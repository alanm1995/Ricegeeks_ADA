# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
Original_2019_data_csv = Path("resources/2019_Registered_Foreclosure_Properties.csv")

# %%
Clean_2019_data = pd.read_csv(
    Original_2019_data_csv, index_col= "Registered Date", infer_datetime_format=True, parse_dates=True)
Clean_2019_data = Clean_2019_data.sort_index()
Clean_2019_data.head()
# Out:
#                         APN  Property Type         Property Address  \
# Registered Date
# 2019-01-01       2502024087  Single Family  13901 W OLIVE VIEW LANE
# 2019-01-01       2415022019   Multi-Family    5648 N CARTWRIGHT AVE
# 2019-01-01       2682021035  Single Family       16840 W DONMETZ ST
# 2019-01-01       2260010015  Single Family        4910 N LIBBIT AVE
# 2019-01-01       5207005011   Multi-Family   3637 1/2 N GRIFFIN AVE
#
#                    Property City Property State  Property Zip  \
# Registered Date
# 2019-01-01           LOS ANGELES             CA         91342
# 2019-01-01       NORTH HOLLYWOOD             CA         91601
# 2019-01-01           LOS ANGELES             CA         91344
# 2019-01-01           LOS ANGELES             CA         91436
# 2019-01-01           LOS ANGELES             CA         90031
#
#                  Council District  \
# Registered Date
# 2019-01-01                      7
# 2019-01-01                      2
# ...

# %%
Clean_2019_data.drop(["APN", "Council District", "Lender Contact", "Lender Contact Phone", "Property Management Contact", 
                      "Property Management Address", "Property Management Contact Phone", "Council Districts", "Neighborhood Councils (Certified)"]
                        , axis = 1, inplace = True)

# %%
Clean_2019_data.head()
# Out:
#                  Property Type         Property Address    Property City  \
# Registered Date
# 2019-01-01       Single Family  13901 W OLIVE VIEW LANE      LOS ANGELES
# 2019-01-01        Multi-Family    5648 N CARTWRIGHT AVE  NORTH HOLLYWOOD
# 2019-01-01       Single Family       16840 W DONMETZ ST      LOS ANGELES
# 2019-01-01       Single Family        4910 N LIBBIT AVE      LOS ANGELES
# 2019-01-01        Multi-Family   3637 1/2 N GRIFFIN AVE      LOS ANGELES
#
#                 Property State  Property Zip  \
# Registered Date
# 2019-01-01                  CA         91342
# 2019-01-01                  CA         91601
# 2019-01-01                  CA         91344
# 2019-01-01                  CA         91436
# 2019-01-01                  CA         90031
#
#                                                             Lender  \
# Registered Date
# 2019-01-01                            US-BANK National Association
# ...
